# %%
# !pip3 install conllu
# !pip3 install transformers
# !pip3 install torch
# !pip3 install datasets

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from probe_bert import BertForMaskedLMProbing
from transformers import pipeline, BertTokenizer, BertConfig

# %%
MODEL_NAME = 'bert-base-uncased'

# %% [markdown]
# ## Model Infers

# %%
tokenizer = BertTokenizer.from_pretrained(MODEL_NAME)
config = BertConfig.from_pretrained(MODEL_NAME)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
sentence = 'The author that the teachers admire [MASK] happy'

# %%
def predictProbe(
    sentence, 
    token_idx,
    alpha,
    probe_layers,
    k,
    topK
):
    
    config.update({
        'TOKEN_IDX': token_idx,
        'ALPHA': alpha,
        'PROBE_LAYERS': probe_layers,
        'K': k,
    })

    probe_model = BertForMaskedLMProbing.from_pretrained(
        MODEL_NAME, config=config
    )

    unmasker = pipeline('fill-mask',
                        model=probe_model,
                        tokenizer=tokenizer,
                        top_k=topK)


    return list(unmasker(sentence))

# %%
def getNumberProbs(masks,
                   candidates=['is', 'are']):
    res = []
    for obj in masks:
        if obj['token_str'] in candidates:
            res.append(obj)
            
    return pd.DataFrame.from_records(res)

try:
    res = getNumberProbs(
        predictProbe(
            sentence ='The author that the teachers admire [MASK] happy',
            token_idx=1,
            alpha=5,
            probe_layers=[0],
            k=(0,50),
            topK = 200
        ), 
        candidates=['is', 'are']).sort_values(by='score', ascending=False).to_string() 
    
    print(res)
    
except KeyError:
    print('No Results have found')
# Out:
# /Users/karahansahin/Desktop/Ellipsis Repos/probe-bert/intervention.py:19: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3618.)
#   lambda_i = torch.tensor([sum(h_i.T * h_i[ix]) for ix in range(h_i.size(0))])
#       score  token token_str                                       sequence
# 0  0.004827   2024       are  the author that the teachers admire are happy
# 1  0.002319   2003        is   the author that the teachers admire is happy

# %% [markdown]
# ## Dataset

# %% [markdown]
# 1. Number Agreement (Subject - Verb)
#     1. Replication of English number
#     1. Binding
#         - They saw itself / themselves
#         - I saw myself / ourselves
#     1. Concord
#         - These men / This men
#         - These men / these man
#         - Five kids / five kid
#     1. Polite, honorific plurality, assoc (For Turkish)
#
# 2. Replicate Number for Turkish
#     - Geldi - geldiler		(pure number)
#     - geldim - geldim-ler - geldik	()
#
# 3. Person
#     - Ben, sen, o, biz, siz, onlar

# %%
dataset_ids = [
    'en_esl',
    'en_ewt',
    'en_gum',
    'en_gumreddit',
    'en_lines',
    'en_partut',
    'en_pronouns',
    'en_pud',
    'tr_boun',
    'tr_gb',
    'tr_imst',
    'tr_pud'
]

# %%
dataset = load_dataset("universal_dependencies", "en_pud")

# %%
pd.DataFrame.from_records(dataset['test'])
# Out:
#            idx                                               text
# 0    n01001011  “While much of the digital transition is unpre...  \
# 1    n01001013  For those who follow social media transitions ...
# 2    n01002017  But in a break from his past rhetoric about cu...
# 3    n01002032  “So I hate to put a little pressure on you, bu...
# 4    n01002042  The new spending is fueled by Clinton’s large ...
# ..         ...                                                ...
# 995  w05010023  Pompey took command of two legions in Capua an...
# 996  w05010024  César was personally informed of Pompey's acti...
# 997  w05010025  Meanwhile, his place in tribune was occupied b...
# 998  w05010026  But when the Senate answered him definitively ...
# 999  w05010027  On the 1st January 49 BC, Marco Antonio read a...
#
#                                                 tokens
# 0    [“, While, much, of, the, digital, transition,...  \
# 1    [For, those, who, follow, social, media, trans...
# 2    [But, in, a, break, from, his, past, rhetoric,...
# 3    [“, So, I, hate, to, put, a, little, pressure,...
# 4    [The, new, spending, is, fueled, by, Clinton, ...
# ..                                                 ...
# 995  [Pompey, took, command, of, two, legions, in, ...
# 996  [César, was, personally, informed, of, Pompey,...
# 997  [Meanwhile, ,, his, place, in, tribune, was, o...
# 998  [But, when, the, Senate, answered, him, defini...
# 999  [On, the, 1st, January, 49, BC, ,, Marco, Anto...
#
#                                                 lemmas
# 0    [“, while, much, of, the, digital, transition,...  \
# 1    [for, those, who, follow, social, media, trans...
# 2    [but, in, a, break, from, he, past, rhetoric, ...
# 3    [“, so, I, hate, to, put, a, little, pressure,...
# 4    [the, new, spending, be, fuel, by, Clinton, ’s...
# ..                                                 ...
# 995  [Pompey, take, command, of, two, legion, in, C...
# 996  [César, be, personally, inform, of, Pompey, 's...
# 997  [meanwhile, ,, he, place, in, tribune, be, occ...
# 998  [but, when, the, senate, answer, he, definitiv...
# 999  [on, the, 1st, January, 49, bc, ,, Marco, Anto...
#
#                                                   upos
# 0    [1, 5, 6, 2, 8, 6, 0, 17, 6, 2, 8, 10, 10, 1, ...  \
# 1    [2, 11, 11, 16, 6, 0, 0, 2, 10, 10, 1, 11, 17,...
# 2    [9, 2, 8, 0, 2, 11, 6, 0, 2, 16, 0, 1, 8, 10, ...
# 3    [1, 14, 11, 16, 7, 16, 8, 6, 0, 2, 11, 1, 9, 8...
# 4              [8, 6, 0, 17, 16, 2, 10, 7, 6, 0, 0, 1]
# ..                                                 ...
# 995  [10, 16, 0, 2, 3, 0, 2, 10, 9, 16, 7, 16, 0, 1...
# 996  [10, 17, 14, 16, 2, 10, 7, 0, 2, 10, 1, 11, 2,...
# 997  [14, 1, 11, 0, 2, 0, 17, 16, 2, 10, 10, 1, 11,...
# 998  [9, 14, 8, 10, 16, 11, 14, 5, 16, 11, 5, 16, 2...
# 999  [2, 8, 6, 10, 3, 0, 1, 10, 10, 16, 8, 0, 2, 10...
#
#                                                   xpos
# 0    [``, IN, JJ, IN, DT, JJ, NN, VBZ, JJ, IN, DT, ...  \
# 1    [IN, DT, WP, VBP, JJ, NN, NNS, IN, NN, NN, ,, ...
# 2    [CC, IN, DT, NN, IN, PRP$, JJ, NN, IN, VBG, NN...
# 3    [``, RB, PRP, VBP, TO, VB, DT, JJ, NN, IN, PRP...
# 4    [DT, JJ, NN, VBZ, VBN, IN, NNP, POS, JJ, NN, N...
# ..                                                 ...
# 995  [NNP, VBD, NN, IN, CD, NNS, IN, NNP, CC, VBD, ...
# 996  [NNP, VBD, RB, VBN, IN, NNP, POS, NNS, IN, NNP...
# 997  [RB, ,, PRP$, NN, IN, NN, VBD, VBN, IN, NNP, N...
# 998  [CC, WRB, DT, NN, VBD, PRP, RB, IN, VBG, PRP, ...
# 999  [IN, DT, JJ, NNP, CD, NN, ,, NNP, NNP, VBD, DT...
#
#                                                  feats
# 0    [None, None, {'Degree': 'Pos'}, None, {'Defini...  \
# 1    [None, {'Number': 'Plur', 'PronType': 'Dem'}, ...
# 2    [None, None, {'Definite': 'Ind', 'PronType': '...
# 3    [None, None, {'Case': 'Nom', 'Number': 'Sing',...
# 4    [{'Definite': 'Def', 'PronType': 'Art'}, {'Deg...
# ..                                                 ...
# 995  [{'Number': 'Sing'}, {'Mood': 'Ind', 'Tense': ...
# 996  [{'Number': 'Sing'}, {'Mood': 'Ind', 'Number':...
# 997  [None, None, {'Gender': 'Masc', 'Number': 'Sin...
# 998  [None, {'PronType': 'Int'}, {'Definite': 'Def'...
# 999  [None, {'Definite': 'Def', 'PronType': 'Art'},...
#
#                                                   head
# 0    [20, 9, 9, 7, 7, 7, 3, 9, 20, 13, 13, 13, 9, 2...  \
# 1    [2, 17, 4, 2, 6, 7, 4, 10, 10, 7, 17, 17, 17, ...
# 2    [16, 4, 4, 16, 8, 8, 8, 4, 10, 8, 10, 16, 15, ...
# 3    [4, 4, 4, 0, 6, 4, 9, 9, 6, 11, 6, 4, 19, 15, ...
# 4             [3, 3, 5, 5, 0, 11, 11, 7, 11, 11, 5, 5]
# ..                                                 ...
# 995  [2, 0, 2, 6, 6, 2, 8, 2, 10, 2, 12, 10, 12, 12...
# 996  [4, 4, 4, 0, 8, 8, 6, 4, 10, 4, 10, 17, 15, 15...
# 997  [8, 8, 4, 8, 6, 4, 8, 0, 10, 8, 10, 14, 14, 10...
# 998  [33, 5, 4, 5, 33, 5, 5, 9, 5, 9, 12, 9, 15, 15...
# 999  [4, 4, 4, 10, 4, 4, 10, 10, 8, 0, 12, 10, 14, ...
#
#                                                 deprel
# 0    [punct, mark, nsubj, case, det, amod, nmod, co...  \
# 1    [case, obl, nsubj, acl:relcl, amod, compound, ...
# 2    [cc, case, det, obl, case, nmod:poss, amod, nm...
# 3    [punct, advmod, nsubj, root, mark, xcomp, det,...
# 4    [det, amod, nsubj:pass, aux:pass, root, case, ...
# ..                                                 ...
# 995  [nsubj, root, obj, case, nummod, obl, case, ob...
# 996  [nsubj:pass, aux:pass, advmod, root, case, nmo...
# 997  [advmod, punct, nmod:poss, nsubj:pass, case, n...
# 998  [cc, advmod, det, nsubj, advcl, obj, advmod, m...
# 999  [case, det, amod, obl, nummod, nmod:npmod, pun...
#
#                                                   deps
# 0    [[('punct', 20)], [('mark', 9)], [('nsubj', 9)...  \
# 1    [[('case', 2)], [('nsubj', 4), ('obl:for', 17)...
# 2    [[('cc', 16)], [('case', 4)], [('det', 4)], [(...
# 3    [[('punct', 4)], [('advmod', 4)], [('nsubj', 4...
# 4    [[('det', 3)], [('amod', 3)], [('nsubj:pass', ...
# ..                                                 ...
# 995  [[('nsubj', 2), ('nsubj', 10), ('nsubj:xsubj',...
# 996  [[('nsubj:pass', 4)], [('aux:pass', 4)], [('ad...
# 997  [[('advmod', 8)], [('punct', 8)], [('nmod:poss...
# 998  [[('cc', 33)], [('advmod', 5)], [('det', 4)], ...
# 999  [[('case', 4)], [('det', 4)], [('amod', 4)], [...
#
#                                                   misc
# 0    [{'SpaceAfter': 'No'}, None, None, None, None,...
# 1    [None, None, None, None, None, None, None, Non...
# 2    [None, None, None, None, None, None, None, Non...
# 3    [{'SpaceAfter': 'No'}, None, None, None, None,...
# 4    [None, None, None, None, None, None, {'SpaceAf...
# ..                                                 ...
# 995  [None, None, None, None, None, None, None, Non...
# 996  [None, None, None, None, None, {'SpaceAfter': ...
# 997  [{'SpaceAfter': 'No'}, None, None, None, None,...
# 998  [None, None, None, None, None, None, None, Non...
# 999  [None, None, None, None, None, {'SpaceAfter': ...
#
# [1000 rows x 11 columns]
