# %%
# !pip3 install conllu
# !pip3 install transformers
# !pip3 install torch
# !pip3 install datasets

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from modules.probe_bert import BertForMaskedLMProbing
from transformers import pipeline, BertTokenizer, BertConfig

# %%
MODEL_NAME = 'bert-base-uncased'

# %% [markdown]
# ## Model Infers

# %%
tokenizer = BertTokenizer.from_pretrained(MODEL_NAME)
config = BertConfig.from_pretrained(MODEL_NAME)

# %%
sentence = 'The author that the teachers admire [MASK] happy'

# %%
def predictProbe(
    sentence, 
    token_idx,
    alpha,
    probe_layers,
    k,
    topK
):
    
    config.update({
        'TOKEN_IDX': token_idx,
        'ALPHA': alpha,
        'PROBE_LAYERS': probe_layers,
        'K': k,
    })

    probe_model = BertForMaskedLMProbing.from_pretrained(
        MODEL_NAME, config=config
    )

    unmasker = pipeline('fill-mask',
                        model=probe_model,
                        tokenizer=tokenizer,
                        top_k=topK)


    return list(unmasker(sentence))

# %%
def getNumberProbs(masks,
                   candidates=['is', 'are']):
    res = []
    for obj in masks:
        if obj['token_str'] in candidates:
            res.append(obj)
            
    return pd.DataFrame.from_records(res)

try:
    res = getNumberProbs(
        predictProbe(
            sentence ='The author that the teachers admire [MASK] happy',
            token_idx=1,
            alpha=5,
            probe_layers=[0],
            k=(0,50),
            topK = 200
        ), 
        candidates=['is', 'are']).sort_values(by='score', ascending=False).to_string() 
    
    print(res)
    
except KeyError:
    print('No Results have found')
# Out:
# /Users/karahansahin/Desktop/Ellipsis Repos/probe-bert/intervention.py:19: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3618.)
#   lambda_i = torch.tensor([sum(h_i.T * h_i[ix]) for ix in range(h_i.size(0))])
#       score  token token_str                                       sequence
# 0  0.004827   2024       are  the author that the teachers admire are happy
# 1  0.002319   2003        is   the author that the teachers admire is happy

# %%
sent = '[MASK] men are good'
print(list(enumerate(tokenizer.tokenize(sent))))
# Out:
# [(0, '[MASK]'), (1, 'men'), (2, 'are'), (3, 'good')]

# %%
res = pd.DataFrame.from_records(
    predictProbe(
        sentence=sent,
        token_idx=0,
        alpha=-5,
        probe_layers=[0],
        k=(0,50),
        topK =1500
    )).sort_values(by='score', ascending=False)

mask = res['token_str'].apply(lambda x: x in ['these', 'this'])
print(res[mask])
# Out:
#         score  token token_str            sequence
# 115  0.000550   2023      this   this men are good
# 531  0.000178   2122     these  these men are good

# %% [markdown]
# ## Dataset

# %% [markdown]
# 1. Number Agreement (Subject - Verb)
#     1. Replication of English number
#     1. Binding
#         - They saw itself / themselves
#         - I saw myself / ourselves
#     1. Concord
#         - These men / This men
#         - These men / these man
#         - Five kids / five kid
#     1. Polite, honorific plurality, assoc (For Turkish)
#
# 2. Replicate Number for Turkish
#     - Geldi - geldiler		(pure number)
#     - geldim - geldim-ler - geldik	()
#
# 3. Person
#     - Ben, sen, o, biz, siz, onlar

# %%
dataset_ids = [
    'en_esl',
    'en_ewt',
    'en_gum',
    'en_gumreddit',
    'en_lines',
    'en_partut',
    'en_pronouns',
    'en_pud',
    'tr_boun',
    'tr_gb',
    'tr_imst',
    'tr_pud'
]

# %%
dataset = load_dataset("universal_dependencies", "en_pud")

# %%
data = pd.DataFrame.from_records(dataset['test'])

# %%
data[data.tokens.apply(lambda x: 'is' in x)]
# Out:
#            idx                                               text
# 0    n01001011  “While much of the digital transition is unpre...  \
# 4    n01002042  The new spending is fueled by Clinton’s large ...
# 18   n01009027  Today, Khanzir may be a lonely pig, but he isn...
# 28   n01015033  It's most obvious when a celebrity's name is i...
# 31   n01016019  Several analysts have suggested Huawei is best...
# ..         ...                                                ...
# 958  w04004005  The inner part of the region is flat and hilly...
# 969  w04009042  The man told him that a war between the two un...
# 974  w04010031  During their various collaborations, it is not...
# 983  w05004031  It is the portion from this second boundary up...
# 989  w05006024  Golden Age Spanish or Early Modern Spanish is ...
#
#                                                 tokens
# 0    [“, While, much, of, the, digital, transition,...  \
# 4    [The, new, spending, is, fueled, by, Clinton, ...
# 18   [Today, ,, Khanzir, may, be, a, lonely, pig, ,...
# 28   [It, 's, most, obvious, when, a, celebrity, 's...
# 31   [Several, analysts, have, suggested, Huawei, i...
# ..                                                 ...
# 958  [The, inner, part, of, the, region, is, flat, ...
# 969  [The, man, told, him, that, a, war, between, t...
# 974  [During, their, various, collaborations, ,, it...
# 983  [It, is, the, portion, from, this, second, bou...
# 989  [Golden, Age, Spanish, or, Early, Modern, Span...
#
#                                                 lemmas
# 0    [“, while, much, of, the, digital, transition,...  \
# 4    [the, new, spending, be, fuel, by, Clinton, ’s...
# 18   [today, ,, Khanzir, may, be, a, lonely, pig, ,...
# 28   [it, be, most, obvious, when, a, celebrity, 's...
# 31   [several, analyst, have, suggest, Huawei, be, ...
# ..                                                 ...
# 958  [the, inner, part, of, the, region, be, flat, ...
# 969  [the, man, tell, he, that, a, war, between, th...
# 974  [during, they, various, collaboration, ,, it, ...
# 983  [it, be, the, portion, from, this, second, bou...
# 989  [golden, age, Spanish, or, early, modern, Span...
#
#                                                   upos
# 0    [1, 5, 6, 2, 8, 6, 0, 17, 6, 2, 8, 10, 10, 1, ...  \
# 4              [8, 6, 0, 17, 16, 2, 10, 7, 6, 0, 0, 1]
# 18   [0, 1, 10, 17, 17, 8, 6, 0, 1, 9, 11, 17, 14, ...
# 28   [11, 17, 14, 6, 14, 8, 0, 7, 0, 17, 14, 14, 6, 1]
# 31   [6, 0, 17, 16, 10, 17, 14, 16, 7, 16, 2, 10, 7...
# ..                                                 ...
# 958  [8, 6, 0, 2, 8, 0, 17, 6, 9, 6, 1, 2, 8, 6, 0,...
# 969  [8, 0, 16, 11, 5, 8, 0, 2, 8, 3, 0, 17, 16, 1,...
# 974  [2, 11, 6, 0, 1, 11, 17, 7, 6, 11, 2, 8, 3, 16...
# 983  [11, 17, 8, 0, 2, 8, 6, 0, 2, 2, 8, 6, 0, 1, 8...
# 989  [6, 0, 10, 9, 6, 6, 10, 17, 8, 0, 2, 8, 0, 11,...
#
#                                                   xpos
# 0    [``, IN, JJ, IN, DT, JJ, NN, VBZ, JJ, IN, DT, ...  \
# 4    [DT, JJ, NN, VBZ, VBN, IN, NNP, POS, JJ, NN, N...
# 18   [NN, ,, NNP, MD, VB, DT, JJ, NN, ,, CC, PRP, V...
# 28   [PRP, VBZ, RBS, JJ, WRB, DT, NN, POS, NN, VBZ,...
# 31   [JJ, NNS, VBP, VBN, NNP, VBZ, RBS, VBN, TO, VB...
# ..                                                 ...
# 958  [DT, JJ, NN, IN, DT, NN, VBZ, JJ, CC, JJ, ,, I...
# 969  [DT, NN, VBD, PRP, IN, DT, NN, IN, DT, CD, NNS...
# 974  [IN, PRP$, JJ, NNS, ,, PRP, VBZ, RB, JJ, WP, I...
# 983  [PRP, VBZ, DT, NN, IN, DT, JJ, NN, RB, IN, DT,...
# 989  [JJ, NN, NNP, CC, JJ, JJ, NNP, VBZ, DT, NN, IN...
#
#                                                  feats
# 0    [None, None, {'Degree': 'Pos'}, None, {'Defini...  \
# 4    [{'Definite': 'Def', 'PronType': 'Art'}, {'Deg...
# 18   [{'Number': 'Sing'}, None, {'Number': 'Sing'},...
# 28   [{'Case': 'Nom', 'Gender': 'Neut', 'Number': '...
# 31   [{'Degree': 'Pos'}, {'Number': 'Plur'}, {'Mood...
# ..                                                 ...
# 958  [{'Definite': 'Def', 'PronType': 'Art'}, {'Deg...
# 969  [{'Definite': 'Def', 'PronType': 'Art'}, {'Num...
# 974  [None, {'Number': 'Plur', 'Person': '3', 'Poss...
# 983  [{'Case': 'Nom', 'Gender': 'Neut', 'Number': '...
# 989  [{'Degree': 'Pos'}, {'Number': 'Sing'}, {'Numb...
#
#                                                   head
# 0    [20, 9, 9, 7, 7, 7, 3, 9, 20, 13, 13, 13, 9, 2...  \
# 4             [3, 3, 5, 5, 0, 11, 11, 7, 11, 11, 5, 5]
# 18   [8, 8, 8, 8, 8, 8, 8, 0, 8, 15, 15, 15, 15, 15...
# 28     [4, 4, 4, 0, 13, 7, 9, 7, 13, 13, 13, 13, 4, 4]
# 31   [2, 4, 4, 0, 8, 8, 8, 4, 10, 8, 14, 14, 12, 10...
# ..                                                 ...
# 958  [3, 3, 8, 6, 6, 3, 8, 0, 10, 8, 8, 15, 15, 15,...
# 969  [2, 3, 0, 3, 13, 7, 13, 11, 11, 11, 7, 13, 3, ...
# 974  [4, 4, 4, 9, 9, 9, 9, 9, 0, 14, 13, 13, 10, 9,...
# 983  [4, 4, 4, 0, 8, 8, 8, 4, 13, 9, 13, 13, 4, 17,...
# 989  [2, 3, 10, 7, 7, 7, 3, 10, 10, 0, 13, 13, 10, ...
#
#                                                 deprel
# 0    [punct, mark, nsubj, case, det, amod, nmod, co...  \
# 4    [det, amod, nsubj:pass, aux:pass, root, case, ...
# 18   [obl:tmod, punct, nsubj, aux, cop, det, amod, ...
# 28   [nsubj, cop, advmod, root, advmod, det, nmod:p...
# 31   [amod, nsubj, aux, root, nsubj:pass, aux:pass,...
# ..                                                 ...
# 958  [det, amod, nsubj, case, det, nmod, cop, root,...
# 969  [det, nsubj, root, iobj, mark, det, nsubj, cas...
# 974  [case, nmod:poss, amod, obl, punct, expl, cop,...
# 983  [nsubj, cop, det, root, case, det, amod, nmod,...
# 989  [amod, amod, nsubj, cc, amod, amod, conj, cop,...
#
#                                                   deps
# 0    [[('punct', 20)], [('mark', 9)], [('nsubj', 9)...  \
# 4    [[('det', 3)], [('amod', 3)], [('nsubj:pass', ...
# 18   [[('obl:tmod', 8)], [('punct', 8)], [('nsubj',...
# 28   [[('nsubj', 4)], [('cop', 4)], [('advmod', 4)]...
# 31   [[('amod', 2)], [('nsubj', 4)], [('aux', 4)], ...
# ..                                                 ...
# 958  [[('det', 3)], [('amod', 3)], [('nsubj', 8), (...
# 969  [[('det', 2)], [('nsubj', 3)], [('root', 0)], ...
# 974  [[('case', 4)], [('nmod:poss', 4)], [('amod', ...
# 983  [[('nsubj', 4)], [('cop', 4)], [('det', 4)], [...
# 989  [[('amod', 2)], [('amod', 3)], [('nsubj', 10)]...
#
#                                                   misc
# 0    [{'SpaceAfter': 'No'}, None, None, None, None,...
# 4    [None, None, None, None, None, None, {'SpaceAf...
# 18   [{'SpaceAfter': 'No'}, None, None, None, None,...
# 28   [{'SpaceAfter': 'No'}, None, None, None, None,...
# 31   [None, None, None, None, None, None, None, Non...
# ..                                                 ...
# 958  [None, None, None, None, None, None, None, Non...
# 969  [None, None, None, None, None, None, None, Non...
# 974  [None, None, None, {'SpaceAfter': 'No'}, None,...
# 983  [None, None, None, None, None, None, None, Non...
# 989  [None, None, None, None, {'Proper': 'True'}, N...
#
# [157 rows x 11 columns]
